# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import numpy as np

# %%
df = pd.read_csv("input.csv")
df
# Out:
#      URL_ID                                                URL
# 0         1  https://insights.blackcoffer.com/how-is-login-...
# 1         2  https://insights.blackcoffer.com/how-does-ai-h...
# 2         3  https://insights.blackcoffer.com/ai-and-its-im...
# 3         4  https://insights.blackcoffer.com/how-do-deep-l...
# 4         5  https://insights.blackcoffer.com/how-artificia...
# ..      ...                                                ...
# 165     167  https://insights.blackcoffer.com/role-big-data...
# 166     168  https://insights.blackcoffer.com/sales-forecas...
# 167     169  https://insights.blackcoffer.com/detect-data-e...
# 168     170  https://insights.blackcoffer.com/data-exfiltra...
# 169     171  https://insights.blackcoffer.com/impacts-of-co...
#
# [170 rows x 2 columns]

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',
}

url  = 'https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/'
page = requests.get(url,headers=headers)
soup = BeautifulSoup(page.text,'html.parser')
# print(soup)

# %%
# tables = soup.find_all("div", {"class": "td-pb-span8 td-main-content"})
# print(tables)

# %%
head = soup.find("h1",{"class":"entry-title"})
tables = soup.find_all("div", {"class": "td-post-content"})
# print(head.text)
# print()
for table in tables :
    url  = 'https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/'
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.text,'html.parser')
    artical = table.find_all("p")
#     print(artical)

# %%
a=0
for ind in df.index:
    a=a+1
    print(a,df['URL'][ind])
    headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',
    }

    url  = df['URL'][ind]
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.text,'html.parser')
    head = soup.find("h1",{"class":"entry-title"})
    tables = soup.find_all("div", {"class": "td-post-content"})
    print(head.text)
    # print()
    for table in tables :
        url  = 'https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/'
        page = requests.get(url,headers=headers)
        soup = BeautifulSoup(page.text,'html.parser')
        artical = table.find_all("p")
        art=(artical)
        print(art)
        print()
        print()
# Out:
# 1 https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/
# How is Login Logout Time Tracking for Employees in Office done by AI?
# ...

# %%
for i, link in df.iterrows():
    print('link----',link,'-------link')

# %%
for ind in df.index:
     print(df['URL'][ind])

# %%
data = pd.read_csv("Loughran-McDonald_MasterDictionary_1993-2021.csv")
data
# Out:
#             Word  Seq_num  Word Count  Word Proportion  Average Proportion  \
# 0       AARDVARK        1         354     1.550080e-08        1.422600e-08
# 1      AARDVARKS        2           3     1.313627e-10        8.653817e-12
# 2          ABACI        3           9     3.940882e-10        1.169679e-10
# 3          ABACK        4          29     1.269840e-09        6.654735e-10
# 4         ABACUS        5        8570     3.752595e-07        3.809464e-07
# ...          ...      ...         ...              ...                 ...
# 86526     ZYGOTE    86529          50     2.189379e-09        8.729336e-10
# 86527    ZYGOTES    86530           1     4.378757e-11        1.809516e-11
# 86528    ZYGOTIC    86531           0     0.000000e+00        0.000000e+00
# 86529  ZYMURGIES    86532           0     0.000000e+00        0.000000e+00
# 86530    ZYMURGY    86533           0     0.000000e+00        0.000000e+00
#
# ...

# %%
a=0
art_dict = {}
for ind in df.index:
    a=a+1
    if a<5 :
        print(a,df['URL'][ind])
        headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',
        }

        url  = df['URL'][ind]
        page = requests.get(url,headers=headers)
        soup = BeautifulSoup(page.text,'html.parser')
        head = soup.find("h1",{"class":"entry-title"})
        tables = soup.find_all("div", {"class": "td-post-content"})
        print(head.text)
        # print()
        for table in tables :
            url  = 'https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/'
            page = requests.get(url,headers=headers)
            soup = BeautifulSoup(page.text,'html.parser')
            artical = table.find("p")
            art=(artical)
#         print(art)
#         arti=' '.join(art)
        arti= u' '.join(art.stripped_strings)
        print(arti)
#         print()
#         print()
        art_dict[a] = [df['URL'][ind],arti]
print(art_dict)

page_art_dict = pd.DataFrame.from_dict(art_dict, orient='index',columns=['URL','arti'])

# page_art_dict.to_csv('page_artical_test.csv')
# print(' '.join(text))
# Out:
# 1 https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/
# How is Login Logout Time Tracking for Employees in Office done by AI?
# When people hear AI they often think about sentient robots and magic boxes. AI today is much more mundane and simple—but that doesn’t mean it’s not powerful. Another misconception is that high-profile research projects can be applied directly to any business situation. AI done right can create an extreme return on investments (ROIs)—for instance through automation or precise prediction. But it does take thought, time, and proper implementation. We have seen that success and value generated by AI projects are increased when there is a grounded understanding and expectation of what the technology can deliver from the C-suite down.
# 2 https://insights.blackcoffer.com/how-does-ai-help-to-monitor-retail-shelf-watches/
# How does AI help to monitor Retail Shelf watches?
# ...

# %%
pov=0
print(test)
# for test in data.index:
#     print(data['Positive'][test])
# for i in text :
#     if i==data['Positive'][test]:
#         pov=pov+1
# Out:
# 52445

# %%
a=['2ewe' , 'fewfr rfwfr','fref rfrr 32 3']
ar=' '.join(a)
print(ar)
# Out:
# 2ewe fewfr rfwfr fref rfrr 32 3

# %%
a=0
art_dict = {}
for ind in df.index:
    a=a+1
    print(a,df['URL'][ind])
    headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',
    }

    url  = df['URL'][ind]
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.text,'html.parser')
    head = soup.find("h1",{"class":"entry-title"})
    tables = soup.find_all("div", {"class": "td-post-content"})
    print(head.text)
    # print()
    for table in tables :
        url  = 'https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/'
        page = requests.get(url,headers=headers)
        soup = BeautifulSoup(page.text,'html.parser')
        artical = table.find("p")
        art=(artical)
#        print(art)
#        arti=' '.join(art)
    arti= u' '.join(art.stripped_strings)
    print(arti)
#         print()
#         print()
    art_dict[a] = [df['URL'][ind],arti]
print(art_dict)

page_art_dict = pd.DataFrame.from_dict(art_dict, orient='index',columns=['URL','arti'])

page_art_dict.to_csv('page_artical_test.csv')
# print(' '.join(text))
# Out:
# 1 https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/
# How is Login Logout Time Tracking for Employees in Office done by AI?
# When people hear AI they often think about sentient robots and magic boxes. AI today is much more mundane and simple—but that doesn’t mean it’s not powerful. Another misconception is that high-profile research projects can be applied directly to any business situation. AI done right can create an extreme return on investments (ROIs)—for instance through automation or precise prediction. But it does take thought, time, and proper implementation. We have seen that success and value generated by AI projects are increased when there is a grounded understanding and expectation of what the technology can deliver from the C-suite down.
# 2 https://insights.blackcoffer.com/how-does-ai-help-to-monitor-retail-shelf-watches/
# How does AI help to monitor Retail Shelf watches?
# ...

# %%
a=0
for i in df.URL :
    if a==2 :
        print(i, df.iloc[a]['URL_ID'])
    a=a+1
# Out:
# https://insights.blackcoffer.com/ai-and-its-impact-on-the-fashion-industry/ 3
